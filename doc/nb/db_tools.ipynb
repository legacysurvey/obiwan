# %% [markdown]
# # Using the PSQL Database for Obiwan

# %%
import psycopg2
import sys
import json

# %%
with open('config.json') as f:
    conf = json.load(f)
conn_str = "host={} dbname={} user={} password={}".format(conf['host'], conf['database'], conf['user'], conf['passw'])

# %%
conn = psycopg2.connect(conn_str)
